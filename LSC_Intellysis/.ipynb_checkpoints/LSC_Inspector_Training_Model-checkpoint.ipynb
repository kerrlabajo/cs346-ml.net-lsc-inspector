# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# C:\Users\raul jay\Desktop\LSC_2

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20  Python-3.10.9 torch-2.0.1+cpu CPU
# Setup complete  (12 CPUs, 15.8 GB RAM, 407.8/475.8 GB disk)

# %%
# Git clone method (for development)

# %cd {HOME}
# !git clone github.com/ultralytics/ultralytics
# %cd {HOME}/ultralytics
# !pip install -e .

# from IPython import display
# display.clear_output()

# import ultralytics
# ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
#!mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="DdKRNxY59PvGqQezPnHM")
project = rf.workspace("intellysis").project("inspector-kzz3n")
dataset = project.version(1).download("yolov8")
# Out:
# C:\Users\raul jay\Desktop\LSC_2\datasets
# Requirement already satisfied: roboflow in c:\users\raul jay\anaconda3\lib\site-packages (1.0.8)
# Requirement already satisfied: certifi==2022.12.7 in c:\users\raul jay\anaconda3\lib\site-packages (from roboflow) (2022.12.7)
# Requirement already satisfied: chardet==4.0.0 in c:\users\raul jay\anaconda3\lib\site-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in c:\users\raul jay\anaconda3\lib\site-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in c:\users\raul jay\anaconda3\lib\site-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\raul jay\anaconda3\lib\site-packages (from roboflow) (1.4.4)
# Requirement already satisfied: matplotlib in c:\users\raul jay\anaconda3\lib\site-packages (from roboflow) (3.7.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\raul jay\anaconda3\lib\site-packages (from roboflow) (1.23.5)
# Requirement already satisfied: opencv-python>=4.1.2 in c:\users\raul jay\anaconda3\lib\site-packages (from roboflow) (4.7.0.72)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\raul jay\anaconda3\lib\site-packages (from roboflow) (9.4.0)
# Requirement already satisfied: pyparsing==2.4.7 in c:\users\raul jay\anaconda3\lib\site-packages (from roboflow) (2.4.7)
# Requirement already satisfied: python-dateutil in c:\users\raul jay\anaconda3\lib\site-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in c:\users\raul jay\anaconda3\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: requests in c:\users\raul jay\anaconda3\lib\site-packages (from roboflow) (2.28.1)
# Requirement already satisfied: six in c:\users\raul jay\anaconda3\lib\site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\raul jay\anaconda3\lib\site-packages (from roboflow) (1.26.14)
# Requirement already satisfied: wget in c:\users\raul jay\anaconda3\lib\site-packages (from roboflow) (3.2)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\raul jay\anaconda3\lib\site-packages (from roboflow) (4.64.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\raul jay\anaconda3\lib\site-packages (from roboflow) (6.0)
# Requirement already satisfied: requests-toolbelt in c:\users\raul jay\anaconda3\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: colorama in c:\users\raul jay\anaconda3\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\raul jay\anaconda3\lib\site-packages (from matplotlib->roboflow) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\raul jay\anaconda3\lib\site-packages (from matplotlib->roboflow) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\raul jay\anaconda3\lib\site-packages (from matplotlib->roboflow) (22.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\raul jay\anaconda3\lib\site-packages (from requests->roboflow) (2.0.4)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Inspector-1 to yolov8: 100% [664516 / 664516] bytes
# Extracting Dataset Version Zip to Inspector-1 in yolov8:: 100%|██| 72/72 [00:00<00:00, 1075.99it/s]

# %%
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data='datasets/Inspector-1/data.yaml' epochs=50 imgsz=800 plots=True
# Out:
# C:\Users\raul jay\Desktop\LSC_2

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train3/val_batch0_labels.jpg', width=600)
# Out:
# C:\Users\raul jay\Desktop\LSC_Intellysis

# %%
Image(filename=f'{HOME}/runs/detect/train3/val_batch0_pred.jpg', width=600)

# %% [markdown]
# ## Test Model

# %%
# !yolo task=detect mode=predict model=runs\detect\train3\weights\best.pt conf=0.25 source='test/Test2.png' save=True
# Out:
# Ultralytics YOLOv8.0.20  Python-3.10.9 torch-2.0.1+cpu CPU
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# image 1/1 C:\Users\raul jay\Desktop\LSC_Intellysis\test\Test2.png: 480x800 1 Component, 2 Solders, 270.6ms
# Speed: 1.0ms pre-process, 270.6ms inference, 3.5ms postprocess per image at shape (1, 3, 800, 800)
# Results saved to runs\detect\predict

# %%
Image(filename='runs/detect/predict/Test2.png', height=600)
